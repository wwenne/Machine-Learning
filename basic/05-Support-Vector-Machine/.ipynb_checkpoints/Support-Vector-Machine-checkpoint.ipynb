# %%
from sklearn.datasets import load_digits
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

digits = load_digits()
df = pd.DataFrame(digits.data,columns = digits.feature_names)
df["target"] = digits.target

import matplotlib.pyplot as plt
plt.scatter(df["pixel_0_2"],df["pixel_0_3"],color = "red",marker = "+")
plt.scatter(df["pixel_0_4"],df["pixel_0_5"],color = "blue",marker = ".")

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

x = df.drop(columns = "target",axis = 1)
y = df["target"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

model_1 = SVR(kernel = "linear",gamma = "auto")
model_1.fit(x_train,y_train)
score0f_1 = model_1.score(x_test,y_test)
print(f"The score of model 1 is {score0f_1}")

model_2 = SVR(gamma = "auto",kernel = "poly")
model_2.fit(x_train,y_train)
score0f_2 = model_2.score(x_test,y_test)
print(f"The score of model 1 is {score0f_2}")
# Out:
# The score of model 1 is 0.50155246685449
# The score of model 1 is 0.8876377231768344
